# %%
import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown
import gradio as gr

# %%
MODEL = 'gpt-5-nano'

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"Successful, current key starts with {openai_api_key[:15]}")
# Out:
# Successful, current key starts with sk-proj-61G7O-j

# %%
message = [{'role':'user', 'content':'My name is virvi huta'}]

message
# Out:
# [{'role': 'user', 'content': 'My name is virvi huta'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model='gpt-5-mini', messages=message)
response.choices[0].message.content
# Out:
# 'Nice to meet you, Virvi Huta. How can I help you today? Would you like me to call you Virvi or something else?'

# %%
def message_gpt(prompt):
    message = [{'role': 'user', 'content': prompt}]
    response = openai.chat.completions.create(model=MODEL, messages=message)
    return response.choices[0].message.content

# %%
def ask_for_input():
    answer = input("Hello, want to talk to gpt?")
    if answer == 'Yes' or answer == 'yes':
        print('okay')
        prompt = input('Ask gpt: ')
        reply = message_gpt(prompt)
        print(reply)
    else:
        print('Okay bye')

# %%
ask_for_input()
# Out:
# okay
# Hi! Nice to meet you. How can I help today? I can:
#
# - Answer questions and explain topics
# - Help with writing (emails, essays, resumes, captions)
# - Summarize or analyze articles
# - Brainstorm ideas or plan something
# - Assist with programming or debugging
# - Translate or practice languages
#
# Tell me what you’d like to do, or drop a task or question, and I’ll jump right in.
